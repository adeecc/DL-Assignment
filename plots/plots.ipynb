# %%
import pandas as pd 
import seaborn as sns 
import matplotlib.pyplot as plt 
import os

# %%
# Set style 
sns.set_style('darkgrid')

# %% [markdown]
# # LOSS

# %%
plt.figure(figsize=(20, 16))
directory = 'loss_data'
for filename in os.listdir(directory):
    path = os.path.join(directory, filename)
    if os.path.isfile(path):
        df = pd.read_csv(path)
        plt.plot(df['Step'], df['Value'], label=path[len(directory) + 1:-14])


plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Loss Curve')
plt.legend()   

plt.savefig('loss_curves.png')

# %% [markdown]
# # Accuracy

# %%
plt.figure(figsize=(20, 14))
directory = 'valacc_data'
for filename in os.listdir(directory):
    path = os.path.join(directory, filename)
    if os.path.isfile(path):
        df = pd.read_csv(path)
        plt.plot(df['Step'], df['Value'], label=path[len(directory) + 1:-14])

plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Accuracy Curve')
plt.legend()  
plt.savefig('val_acc_curves')

# %%
# Table - 1
plt.figure(figsize=(20, 14))
directory = 'table_1'
for filename in os.listdir(directory):
    path = os.path.join(directory, filename)
    if os.path.isfile(path):
        df = pd.read_csv(path)
        plt.plot(df['Step'], df['Value'], label=path[len(directory) + 1:-14])

plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Accuracy Curve')
plt.legend()  
plt.savefig('table_1')

# %%
# Table - 2
plt.figure(figsize=(20, 14))
directory = 'table_2'
for filename in os.listdir(directory):
    path = os.path.join(directory, filename)
    if os.path.isfile(path):
        df = pd.read_csv(path)
        plt.plot(df['Step'], df['Value'], label=path[len(directory) + 1:-14])

plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Accuracy Curve')
plt.legend()  
plt.savefig('table_2')

# %%
# table 3
plt.figure(figsize=(20, 14))
directory = 'table_3'
for filename in os.listdir(directory):
    path = os.path.join(directory, filename)
    if os.path.isfile(path):
        df = pd.read_csv(path)
        plt.plot(df['Step'], df['Value'], label=path[len(directory) + 1:-14])

plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Accuracy Curve')
plt.legend()  
plt.savefig('table_3')

# %%
# table 4
plt.figure(figsize=(20, 14))
directory = 'table_4'
for filename in os.listdir(directory):
    path = os.path.join(directory, filename)
    if os.path.isfile(path):
        df = pd.read_csv(path)
        plt.plot(df['Step'], df['Value'], label=path[len(directory) + 1:-14])

plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Accuracy Curve')
plt.legend()  
plt.savefig('table_4')

# %%
# table 5
plt.figure(figsize=(20, 14))
directory = 'table_5'
for filename in os.listdir(directory):
    path = os.path.join(directory, filename)
    if os.path.isfile(path):
        df = pd.read_csv(path)
        plt.plot(df['Step'], df['Value'], label=path[len(directory) + 1:-14])

plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Accuracy Curve')
plt.legend()  
plt.savefig('table_5')

# %%
# table 6 
plt.figure(figsize=(20, 14))
directory = 'table_6'
for filename in os.listdir(directory):
    path = os.path.join(directory, filename)
    if os.path.isfile(path):
        df = pd.read_csv(path)
        plt.plot(df['Step'], df['Value'], label=path[len(directory) + 1:-14])

plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Accuracy Curve')
plt.legend()  
plt.savefig('table_6')

# %%
# table 7
plt.figure(figsize=(20, 14))
directory = 'table_7'
for filename in os.listdir(directory):
    path = os.path.join(directory, filename)
    if os.path.isfile(path):
        df = pd.read_csv(path)
        plt.plot(df['Step'], df['Value'], label=path[len(directory) + 1:-14])

plt.xlabel('Steps')
plt.ylabel('Loss')
plt.title('Accuracy Curve')
plt.legend()  
plt.savefig('table_7')
